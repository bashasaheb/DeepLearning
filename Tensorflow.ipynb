# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical

# Load and preprocess the MNIST dataset
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
train_images = train_images.reshape((60000, 28, 28, 1)).astype('float32') / 255
test_images = test_images.reshape((10000, 28, 28, 1)).astype('float32') / 255

train_labels = to_categorical(train_labels)
test_labels = to_categorical(test_labels)

# Define a function to create and compile a model with different configurations
def create_compile_model(activation_function, layer_size):
    model = models.Sequential()
    model.add(layers.Flatten(input_shape=(28, 28, 1)))
    model.add(layers.Dense(layer_size, activation=activation_function))
    model.add(layers.Dense(10, activation='softmax'))

    model.compile(optimizer='adam',
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])
    return model

# Experiment with different activation functions and layer sizes
activation_functions = ['relu', 'sigmoid', 'tanh']
layer_sizes = [32, 64, 128]

for activation_function in activation_functions:
    for layer_size in layer_sizes:
        model = create_compile_model(activation_function, layer_size)

        # Train the model
        model.fit(train_images, train_labels, epochs=5, batch_size=64, validation_data=(test_images, test_labels))

        # Evaluate the model on the test set
        test_loss, test_acc = model.evaluate(test_images, test_labels)
        print(f"Activation Function: {activation_function}, Layer Size: {layer_size}")
        print(f"Test Accuracy: {test_acc}\n")
# Out:
# Epoch 1/5
# 938/938 [==============================] - 3s 2ms/step - loss: 0.4012 - accuracy: 0.8920 - val_loss: 0.2253 - val_accuracy: 0.9339
# Epoch 2/5
# 938/938 [==============================] - 2s 2ms/step - loss: 0.2053 - accuracy: 0.9413 - val_loss: 0.1750 - val_accuracy: 0.9498
# Epoch 3/5
# 938/938 [==============================] - 2s 2ms/step - loss: 0.1640 - accuracy: 0.9532 - val_loss: 0.1558 - val_accuracy: 0.9552
# Epoch 4/5
# 938/938 [==============================] - 2s 2ms/step - loss: 0.1386 - accuracy: 0.9606 - val_loss: 0.1358 - val_accuracy: 0.9613
# Epoch 5/5
# 938/938 [==============================] - 2s 2ms/step - loss: 0.1204 - accuracy: 0.9652 - val_loss: 0.1233 - val_accuracy: 0.9630
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1233 - accuracy: 0.9630
# Activation Function: relu, Layer Size: 32
# Test Accuracy: 0.9629999995231628
#
# Epoch 1/5
# 938/938 [==============================] - 3s 3ms/step - loss: 0.3461 - accuracy: 0.9033 - val_loss: 0.2019 - val_accuracy: 0.9411
# Epoch 2/5
# 938/938 [==============================] - 2s 2ms/step - loss: 0.1693 - accuracy: 0.9512 - val_loss: 0.1427 - val_accuracy: 0.9590
# Epoch 3/5
# 938/938 [==============================] - 2s 2ms/step - loss: 0.1250 - accuracy: 0.9636 - val_loss: 0.1189 - val_accuracy: 0.9648
# Epoch 4/5
# 938/938 [==============================] - 2s 2ms/step - loss: 0.1001 - accuracy: 0.9704 - val_loss: 0.1028 - val_accuracy: 0.9694
# Epoch 5/5
# 938/938 [==============================] - 2s 2ms/step - loss: 0.0825 - accuracy: 0.9755 - val_loss: 0.0991 - val_accuracy: 0.9700
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0991 - accuracy: 0.9700
# Activation Function: relu, Layer Size: 64
# Test Accuracy: 0.9700000286102295
#
# Epoch 1/5
# 938/938 [==============================] - 3s 3ms/step - loss: 0.3009 - accuracy: 0.9159 - val_loss: 0.1590 - val_accuracy: 0.9538
# Epoch 2/5
# 938/938 [==============================] - 3s 3ms/step - loss: 0.1360 - accuracy: 0.9614 - val_loss: 0.1224 - val_accuracy: 0.9648
# Epoch 3/5
# 938/938 [==============================] - 2s 2ms/step - loss: 0.0938 - accuracy: 0.9723 - val_loss: 0.0894 - val_accuracy: 0.9729
# Epoch 4/5
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0712 - accuracy: 0.9786 - val_loss: 0.0847 - val_accuracy: 0.9742
# Epoch 5/5
# 938/938 [==============================] - 2s 3ms/step - loss: 0.0553 - accuracy: 0.9839 - val_loss: 0.0787 - val_accuracy: 0.9767
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0787 - accuracy: 0.9767
# Activation Function: relu, Layer Size: 128
# Test Accuracy: 0.9767000079154968
#
# Epoch 1/5
# 938/938 [==============================] - 3s 2ms/step - loss: 0.7171 - accuracy: 0.8457 - val_loss: 0.3503 - val_accuracy: 0.9145
# Epoch 2/5
# 938/938 [==============================] - 2s 2ms/step - loss: 0.3051 - accuracy: 0.9187 - val_loss: 0.2616 - val_accuracy: 0.9273
# Epoch 3/5
# 938/938 [==============================] - 2s 2ms/step - loss: 0.2458 - accuracy: 0.9317 - val_loss: 0.2263 - val_accuracy: 0.9355
# Epoch 4/5
# 938/938 [==============================] - 2s 2ms/step - loss: 0.2141 - accuracy: 0.9397 - val_loss: 0.2059 - val_accuracy: 0.9410
# Epoch 5/5
# 938/938 [==============================] - 2s 2ms/step - loss: 0.1920 - accuracy: 0.9459 - val_loss: 0.1887 - val_accuracy: 0.9448
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1887 - accuracy: 0.9448
# Activation Function: sigmoid, Layer Size: 32
# Test Accuracy: 0.9448000192642212
#
# Epoch 1/5
# 938/938 [==============================] - 3s 2ms/step - loss: 0.5862 - accuracy: 0.8601 - val_loss: 0.2910 - val_accuracy: 0.9211
# Epoch 2/5
# 938/938 [==============================] - 2s 2ms/step - loss: 0.2580 - accuracy: 0.9286 - val_loss: 0.2196 - val_accuracy: 0.9368
# Epoch 3/5
# 938/938 [==============================] - 2s 2ms/step - loss: 0.2025 - accuracy: 0.9432 - val_loss: 0.1839 - val_accuracy: 0.9454
# Epoch 4/5
# 938/938 [==============================] - 2s 2ms/step - loss: 0.1697 - accuracy: 0.9520 - val_loss: 0.1594 - val_accuracy: 0.9533
# Epoch 5/5
# 938/938 [==============================] - 2s 2ms/step - loss: 0.1473 - accuracy: 0.9580 - val_loss: 0.1477 - val_accuracy: 0.9565
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1477 - accuracy: 0.9565
# Activation Function: sigmoid, Layer Size: 64
# Test Accuracy: 0.9564999938011169
#
# Epoch 1/5
# 938/938 [==============================] - 3s 3ms/step - loss: 0.4774 - accuracy: 0.8813 - val_loss: 0.2582 - val_accuracy: 0.9278
# Epoch 2/5
# 938/938 [==============================] - 3s 3ms/step - loss: 0.2301 - accuracy: 0.9344 - val_loss: 0.1990 - val_accuracy: 0.9427
# Epoch 3/5
# 938/938 [==============================] - 2s 3ms/step - loss: 0.1779 - accuracy: 0.9489 - val_loss: 0.1627 - val_accuracy: 0.9521
# Epoch 4/5
# 938/938 [==============================] - 2s 3ms/step - loss: 0.1437 - accuracy: 0.9580 - val_loss: 0.1403 - val_accuracy: 0.9583
# Epoch 5/5
# 938/938 [==============================] - 3s 3ms/step - loss: 0.1199 - accuracy: 0.9659 - val_loss: 0.1233 - val_accuracy: 0.9626
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1233 - accuracy: 0.9626
# Activation Function: sigmoid, Layer Size: 128
# Test Accuracy: 0.9625999927520752
#
# Epoch 1/5
# 938/938 [==============================] - 3s 2ms/step - loss: 0.4177 - accuracy: 0.8907 - val_loss: 0.2443 - val_accuracy: 0.9310
# Epoch 2/5
# 938/938 [==============================] - 2s 2ms/step - loss: 0.2199 - accuracy: 0.9384 - val_loss: 0.1876 - val_accuracy: 0.9447
# Epoch 3/5
# 938/938 [==============================] - 2s 2ms/step - loss: 0.1755 - accuracy: 0.9499 - val_loss: 0.1585 - val_accuracy: 0.9535
# Epoch 4/5
# 938/938 [==============================] - 2s 2ms/step - loss: 0.1478 - accuracy: 0.9579 - val_loss: 0.1465 - val_accuracy: 0.9571
# Epoch 5/5
# 938/938 [==============================] - 2s 2ms/step - loss: 0.1288 - accuracy: 0.9634 - val_loss: 0.1330 - val_accuracy: 0.9587
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1330 - accuracy: 0.9587
# Activation Function: tanh, Layer Size: 32
# Test Accuracy: 0.9587000012397766
#
# Epoch 1/5
# 938/938 [==============================] - 3s 3ms/step - loss: 0.3572 - accuracy: 0.9017 - val_loss: 0.2106 - val_accuracy: 0.9387
# Epoch 2/5
# 938/938 [==============================] - 2s 2ms/step - loss: 0.1847 - accuracy: 0.9482 - val_loss: 0.1522 - val_accuracy: 0.9556
# Epoch 3/5
# 938/938 [==============================] - 2s 2ms/step - loss: 0.1384 - accuracy: 0.9604 - val_loss: 0.1343 - val_accuracy: 0.9623
# Epoch 4/5
# 938/938 [==============================] - 2s 2ms/step - loss: 0.1110 - accuracy: 0.9688 - val_loss: 0.1110 - val_accuracy: 0.9664
# Epoch 5/5
# 938/938 [==============================] - 2s 2ms/step - loss: 0.0925 - accuracy: 0.9737 - val_loss: 0.1020 - val_accuracy: 0.9694
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1020 - accuracy: 0.9694
# Activation Function: tanh, Layer Size: 64
# Test Accuracy: 0.9693999886512756
#
# Epoch 1/5
# 938/938 [==============================] - 3s 3ms/step - loss: 0.3213 - accuracy: 0.9086 - val_loss: 0.1903 - val_accuracy: 0.9456
# Epoch 2/5
# 938/938 [==============================] - 2s 3ms/step - loss: 0.1621 - accuracy: 0.9534 - val_loss: 0.1317 - val_accuracy: 0.9635
# Epoch 3/5
# 938/938 [==============================] - 3s 3ms/step - loss: 0.1134 - accuracy: 0.9678 - val_loss: 0.1088 - val_accuracy: 0.9680
# Epoch 4/5
# 938/938 [==============================] - 2s 3ms/step - loss: 0.0862 - accuracy: 0.9754 - val_loss: 0.0919 - val_accuracy: 0.9722
# Epoch 5/5
# 938/938 [==============================] - 2s 3ms/step - loss: 0.0675 - accuracy: 0.9812 - val_loss: 0.0865 - val_accuracy: 0.9734
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0865 - accuracy: 0.9734
# Activation Function: tanh, Layer Size: 128
# Test Accuracy: 0.9733999967575073
